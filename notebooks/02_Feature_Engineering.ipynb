# %% [markdown]
# # Load data

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.impute import KNNImputer


# Load the CSV data
train_csv = pd.read_csv('../data/raw/train.csv')

# Load the JSON-derived groups data
train_groups_df = pd.read_pickle('../data/processed/train_groups_df.pkl')  # Assuming you saved this as a pickle

# Inspect the data
display(train_csv.head())
display(train_groups_df.head())
# Out:
#    user_id  target      name     sex         dob   location  \
# 0        0       1    Halina     NaN  1982-08-07    Piastów
# 1        1       0  Eustachy    male  1971-10-28    Sokółka
# 2        2       1      Egon     NaN  2000-07-05  Łaskarzew
# 3        3       0   Eulalia  female  1992-06-10  Bydgoszcz
# 4        4       0    Hilary     NaN  1975-01-09   Osieczna
#
#    location_population location_from  location_from_population  \
# 0                22732       Piastów                     22732
# 1                18331       Sokółka                     18331
# 2                 4879     Łaskarzew                      4879
# 3               352313     Bydgoszcz                    352313
# 4                 2322        Poznań                    538633
#
#                                     occupation  \
# 0                       Teaching professionals
# 1                  General and keyboard clerks
# 2                  Protective services workers
# 3                     Customer services clerks
# 4  Refuse workers and other elementary workers
#
#                                      hobbies  daily_commute  friends_number  \
# 0                                    Fitness           46.0             196
# 1  LARPing,Foreign language learning,Netball           55.0             243
# 2                       Bodybuilding,Kabaddi           90.0             191
# 3                                  Badminton           88.0             164
# 4              Fitness,Embroidery,Lacemaking           40.0             119
#
#   relationship_status  education credit_card_type
# 0              Single        NaN             Visa
# 1              Single        NaN              NaN
# 2     In relationship        3.0              NaN
# 3     In relationship        3.0             Visa
# 4   Married with kids        5.0              NaN
#                                             group_name  \
# 0 0  Let's excercise together and lose a few kilo q...
#   1                              Strongman competition
#   2                                   Fast food 4 life
#   3  alternative medicine - Hypnosis and bioenergot...
# 1 0                                   Tom Cruise group
#
#                     date_joined  year_joined  month_joined  weekday_joined
# 0 0  2008-09-05 09:55:18.730066         2008             9               4
#   1  2008-05-22 21:25:22.572365         2008             5               3
#   2  2012-02-02 05:26:01.293628         2012             2               3
#   3  2008-07-05 05:47:12.254848         2008             7               5
# 1 0  2009-06-14 16:48:28.606142         2009             6               6

# %% [markdown]
# # Data engineering

# %% [markdown]
# ### Remove irrelevant columns

# %%
# Drop columns with low utility for modeling
columns_to_drop = ['name']
train_csv = train_csv.drop(columns=columns_to_drop)

# %% [markdown]
# ### Feature engineering

# %%
train_csv['dob'] = pd.to_datetime(train_csv['dob'], errors='coerce')  # Handle invalid dates
train_csv['age'] = datetime.now().year - train_csv['dob'].dt.year

# Remove 'dob' after transformation
train_csv = train_csv.drop(columns=['dob'])

# %%
# Bin locations by population size
bins = [0, 5000, 20000, 50000, 100000, np.inf]
labels = ['Rural', 'Small Town', 'Town', 'City', 'Metro']
train_csv['location_category'] = pd.cut(train_csv['location_population'], bins=bins, labels=labels)
train_csv['location_from_category'] = pd.cut(train_csv['location_from_population'], bins=bins, labels=labels)

# Remove columns after binning
train_csv = train_csv.drop(columns=['location_population', 'location_from_population', 'location', 'location_from'])

# %% [markdown]
# ### Data from groups joined

# %%
# Number of groups joined by each user
group_counts = train_groups_df.groupby(level=0)['group_name'].count()
group_counts

# train_csv = train_csv.merge(group_counts, left_on='user_id', right_index=True, how='left')
# train_csv['group_count'] = pd.concat([group_counts], axis=1, keys=['group_count'], sort=True)['group_count']
# Out:
# 0       4
# 1       5
# 10      2
# 100     5
# 1000    9
#        ..
# 995     5
# 996     1
# 997     3
# 998     3
# 999     1
# Name: group_name, Length: 3944, dtype: int64

# %%
# Perform one-hot encoding for the specified columns
categorical_columns = ['sex', 'occupation', 'relationship_status', 'credit_card_type']

# Use pd.get_dummies to one-hot encode the columns
train_csv = pd.get_dummies(train_csv, columns=categorical_columns, drop_first=True)

# %%
# Display updated DataFrame
train_csv.head()
# Out:
#    user_id  target                                    hobbies  daily_commute  \
# 0        0       1                                    Fitness           46.0
# 1        1       0  LARPing,Foreign language learning,Netball           55.0
# 2        2       1                       Bodybuilding,Kabaddi           90.0
# 3        3       0                                  Badminton           88.0
# 4        4       0              Fitness,Embroidery,Lacemaking           40.0
#
#    friends_number  education   age location_category location_from_category  \
# 0             196        NaN  42.0              Town                   Town
# 1             243        NaN  53.0        Small Town             Small Town
# 2             191        3.0  24.0             Rural                  Rural
# 3             164        3.0  32.0             Metro                  Metro
# 4             119        5.0  49.0             Rural                  Metro
#
#    sex_male  ...  occupation_Street and related sales and service workers  \
# 0     False  ...                                              False
# 1      True  ...                                              False
# 2     False  ...                                              False
# 3     False  ...                                              False
# 4     False  ...                                              False
#
#    occupation_Subsistence farmers, fishers, hunters and gatherers  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    occupation_Teaching professionals  relationship_status_In relationship  \
# 0                               True                                False
# 1                              False                                False
# 2                              False                                 True
# 3                              False                                 True
# 4                              False                                False
#
#    relationship_status_Married  relationship_status_Married with kids  \
# 0                        False                                  False
# 1                        False                                  False
# 2                        False                                  False
# 3                        False                                  False
# 4                        False                                   True
#
#    relationship_status_Single  credit_card_type_Mastercard  \
# 0                        True                        False
# 1                        True                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#    credit_card_type_Revolut  credit_card_type_Visa
# 0                     False                   True
# 1                     False                  False
# 2                     False                  False
# 3                     False                   True
# 4                     False                  False
#
# [5 rows x 59 columns]

# %% [markdown]
# ### Missing values

# %%
# Initialize KNN Imputer
imputer = KNNImputer(n_neighbors=5)

# Select only numerical columns for KNN Imputation
numeric_columns = ['daily_commute', 'age']
train_csv[numeric_columns] = imputer.fit_transform(train_csv[numeric_columns])

# Create a missing indicator
train_csv['education_missing'] = train_csv['education'].isnull().astype(int)

# Impute missing values with the median
train_csv['education'] = train_csv['education'].fillna(train_csv['education'].median())

# %%
print(train_csv.isnull().sum())
# Out:
# user_id                                                                                           0
# target                                                                                            0
# hobbies                                                                                         680
# daily_commute                                                                                     0
# friends_number                                                                                    0
# education                                                                                         0
# age                                                                                               0
# location_category                                                                                 0
# location_from_category                                                                            0
# sex_male                                                                                          0
# occupation_Agricultural, forestry and fishery labourers                                           0
# occupation_Armed forces occupations, other ranks                                                  0
# occupation_Assemblers                                                                             0
# occupation_Building and related trades workers, excluding electricians                            0
# occupation_Business and administration associate professionals                                    0
# occupation_Business and administration professionals                                              0
# occupation_Chief executives, senior officials and legislators                                     0
# occupation_Cleaners and helpers                                                                   0
# occupation_Commissioned armed forces officers                                                     0
# occupation_Customer services clerks                                                               0
# occupation_Drivers and mobile plant operators                                                     0
# occupation_Electrical and electronic trades workers                                               0
# occupation_Food preparation assistants                                                            0
# occupation_Food processing, wood working, garment and other craft and related trades workers      0
# occupation_General and keyboard clerks                                                            0
# occupation_Handicraft and printing workers                                                        0
# occupation_Health associate professionals                                                         0
# occupation_Health professionals                                                                   0
# occupation_Hospitality, retail and other services managers                                        0
# occupation_Information and communications technicians                                             0
# occupation_Information and communications technology professionals                                0
# occupation_Labourers in mining, construction, manufacturing and transport                         0
# occupation_Legal, social and cultural professionals                                               0
# occupation_Legal, social, cultural and related associate professionals                            0
# occupation_Market-oriented skilled agricultural workers                                           0
# occupation_Market-oriented skilled forestry, fishery and hunting workers                          0
# occupation_Metal, machinery and related trades workers                                            0
# occupation_Non-commissioned armed forces officers                                                 0
# occupation_Numerical and material recording clerks                                                0
# occupation_Other clerical support workers                                                         0
# occupation_Personal care workers                                                                  0
# occupation_Personal service workers                                                               0
# occupation_Production and specialised services managers                                           0
# occupation_Protective services workers                                                            0
# occupation_Refuse workers and other elementary workers                                            0
# occupation_Sales workers                                                                          0
# occupation_Science and engineering associate professionals                                        0
# occupation_Science and engineering professionals                                                  0
# occupation_Stationary plant and machine operators                                                 0
# occupation_Street and related sales and service workers                                           0
# occupation_Subsistence farmers, fishers, hunters and gatherers                                    0
# occupation_Teaching professionals                                                                 0
# relationship_status_In relationship                                                               0
# relationship_status_Married                                                                       0
# relationship_status_Married with kids                                                             0
# relationship_status_Single                                                                        0
# credit_card_type_Mastercard                                                                       0
# credit_card_type_Revolut                                                                          0
# credit_card_type_Visa                                                                             0
# education_missing                                                                                 0
# dtype: int64

# %%
# hobbies -> bert -> embeddings -> clustering -> insights (new columns?)

# %% [markdown]
# # EDA followup

# %%
train_csv.isnull().sum()
# Out:
# user_id                                                                                           0
# target                                                                                            0
# hobbies                                                                                         680
# daily_commute                                                                                     0
# friends_number                                                                                    0
# education                                                                                         0
# age                                                                                               0
# location_category                                                                                 0
# location_from_category                                                                            0
# sex_male                                                                                          0
# occupation_Agricultural, forestry and fishery labourers                                           0
# occupation_Armed forces occupations, other ranks                                                  0
# occupation_Assemblers                                                                             0
# occupation_Building and related trades workers, excluding electricians                            0
# occupation_Business and administration associate professionals                                    0
# occupation_Business and administration professionals                                              0
# occupation_Chief executives, senior officials and legislators                                     0
# occupation_Cleaners and helpers                                                                   0
# occupation_Commissioned armed forces officers                                                     0
# occupation_Customer services clerks                                                               0
# occupation_Drivers and mobile plant operators                                                     0
# occupation_Electrical and electronic trades workers                                               0
# occupation_Food preparation assistants                                                            0
# occupation_Food processing, wood working, garment and other craft and related trades workers      0
# occupation_General and keyboard clerks                                                            0
# occupation_Handicraft and printing workers                                                        0
# occupation_Health associate professionals                                                         0
# occupation_Health professionals                                                                   0
# occupation_Hospitality, retail and other services managers                                        0
# occupation_Information and communications technicians                                             0
# occupation_Information and communications technology professionals                                0
# occupation_Labourers in mining, construction, manufacturing and transport                         0
# occupation_Legal, social and cultural professionals                                               0
# occupation_Legal, social, cultural and related associate professionals                            0
# occupation_Market-oriented skilled agricultural workers                                           0
# occupation_Market-oriented skilled forestry, fishery and hunting workers                          0
# occupation_Metal, machinery and related trades workers                                            0
# occupation_Non-commissioned armed forces officers                                                 0
# occupation_Numerical and material recording clerks                                                0
# occupation_Other clerical support workers                                                         0
# occupation_Personal care workers                                                                  0
# occupation_Personal service workers                                                               0
# occupation_Production and specialised services managers                                           0
# occupation_Protective services workers                                                            0
# occupation_Refuse workers and other elementary workers                                            0
# occupation_Sales workers                                                                          0
# occupation_Science and engineering associate professionals                                        0
# occupation_Science and engineering professionals                                                  0
# occupation_Stationary plant and machine operators                                                 0
# occupation_Street and related sales and service workers                                           0
# occupation_Subsistence farmers, fishers, hunters and gatherers                                    0
# occupation_Teaching professionals                                                                 0
# relationship_status_In relationship                                                               0
# relationship_status_Married                                                                       0
# relationship_status_Married with kids                                                             0
# relationship_status_Single                                                                        0
# credit_card_type_Mastercard                                                                       0
# credit_card_type_Revolut                                                                          0
# credit_card_type_Visa                                                                             0
# education_missing                                                                                 0
# dtype: int64

# %%
train_csv.head()
# Out:
#    user_id  target                                    hobbies  daily_commute  \
# 0        0       1                                    Fitness           46.0
# 1        1       0  LARPing,Foreign language learning,Netball           55.0
# 2        2       1                       Bodybuilding,Kabaddi           90.0
# 3        3       0                                  Badminton           88.0
# 4        4       0              Fitness,Embroidery,Lacemaking           40.0
#
#    friends_number  education   age location_category location_from_category  \
# 0             196        4.0  42.0              Town                   Town
# 1             243        4.0  53.0        Small Town             Small Town
# 2             191        3.0  24.0             Rural                  Rural
# 3             164        3.0  32.0             Metro                  Metro
# 4             119        5.0  49.0             Rural                  Metro
#
#    sex_male  ...  \
# 0     False  ...
# 1      True  ...
# 2     False  ...
# 3     False  ...
# 4     False  ...
#
#    occupation_Subsistence farmers, fishers, hunters and gatherers  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    occupation_Teaching professionals  relationship_status_In relationship  \
# 0                               True                                False
# 1                              False                                False
# 2                              False                                 True
# 3                              False                                 True
# 4                              False                                False
#
#    relationship_status_Married  relationship_status_Married with kids  \
# 0                        False                                  False
# 1                        False                                  False
# 2                        False                                  False
# 3                        False                                  False
# 4                        False                                   True
#
#    relationship_status_Single  credit_card_type_Mastercard  \
# 0                        True                        False
# 1                        True                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#    credit_card_type_Revolut  credit_card_type_Visa  education_missing
# 0                     False                   True                  1
# 1                     False                  False                  1
# 2                     False                  False                  0
# 3                     False                   True                  0
# 4                     False                  False                  0
#
# [5 rows x 60 columns]
